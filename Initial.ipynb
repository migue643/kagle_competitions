# %% [markdown]
# # Analizing tweets to know if they are from a real dissaster

# %%
#imports
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from nltk.stem import WordNetLemmatizer, PorterStemmer
import nltk
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.naive_bayes import MultinomialNB
from sklearn.model_selection import cross_validate

# %% [markdown]
# ## Loading data

# %%
train = pd.read_csv("data/train.csv")
test = pd.read_csv("data/test.csv")
sample_submission = pd.read_csv("data/sample_submission.csv")

# %%
#Taking a look at the data
train.head(5)
# Out:
#    id keyword location                                               text  \
# 0   1     NaN      NaN  Our Deeds are the Reason of this #earthquake M...
# 1   4     NaN      NaN             Forest fire near La Ronge Sask. Canada
# 2   5     NaN      NaN  All residents asked to 'shelter in place' are ...
# 3   6     NaN      NaN  13,000 people receive #wildfires evacuation or...
# 4   7     NaN      NaN  Just got sent this photo from Ruby #Alaska as ...
#
#    target
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1

# %% [markdown]
# ## Analisys

# %%
#We have a lot of nan values in location and in keyword
train.isna().sum()
# Out:
# id             0
# keyword       61
# location    2533
# text           0
# target         0
# dtype: int64

# %%
train.describe()
# Out:
#                  id      target
# count   7613.000000  7613.00000
# mean    5441.934848     0.42966
# std     3137.116090     0.49506
# min        1.000000     0.00000
# 25%     2734.000000     0.00000
# 50%     5408.000000     0.00000
# 75%     8146.000000     1.00000
# max    10873.000000     1.00000

# %%
#The dataset is unbalanced
a = train[train['target'] == 1].count()
b = train[train['target'] == 0].count()

# %%
#Lets take the baseline prediction
baseline = b['target']/7613*100

# %% [markdown]
# ## Text cleaning

# %%
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords 
import string

# %%
train.drop_duplicates()
# Out:
#          id keyword location  \
# 0         1     NaN      NaN
# 1         4     NaN      NaN
# 2         5     NaN      NaN
# 3         6     NaN      NaN
# 4         7     NaN      NaN
# ...     ...     ...      ...
# 7608  10869     NaN      NaN
# 7609  10870     NaN      NaN
# 7610  10871     NaN      NaN
# 7611  10872     NaN      NaN
# 7612  10873     NaN      NaN
#
#                                                    text  target
# 0     Our Deeds are the Reason of this #earthquake M...       1
# 1                Forest fire near La Ronge Sask. Canada       1
# 2     All residents asked to 'shelter in place' are ...       1
# 3     13,000 people receive #wildfires evacuation or...       1
# 4     Just got sent this photo from Ruby #Alaska as ...       1
# ...                                                 ...     ...
# 7608  Two giant cranes holding a bridge collapse int...       1
# 7609  @aria_ahrary @TheTawniest The out of control w...       1
# 7610  M1.94 [01:04 UTC]?5km S of Volcano Hawaii. htt...       1
# 7611  Police investigating after an e-bike collided ...       1
# 7612  The Latest: More Homes Razed by Northern Calif...       1
#
# [7613 rows x 5 columns]

# %%
train[train['keyword'].isna() == False]['keyword']
# Out:
# 31       ablaze
# 32       ablaze
# 33       ablaze
# 34       ablaze
# 35       ablaze
#          ...
# 7578    wrecked
# 7579    wrecked
# 7580    wrecked
# 7581    wrecked
# 7582    wrecked
# Name: keyword, Length: 7552, dtype: object

# %%
lemmatizer = WordNetLemmatizer()
w_tokenizer = nltk.tokenize.WhitespaceTokenizer()

# %%
#Lets lemmatize the keywords
lista = []
i=0
ps = PorterStemmer()
for keyword in train['keyword']:
    lista.append(ps.stem(str(keyword).replace("%20"," ")))
    
# for key,text in zip(lista,train['text']):
#     if key == "nan":
#         for key_2 in lista:
#             if key_2 in text:
#                 key = key_2

# %%
lista
# Out:
# ['nan',
#  'nan',
#  'nan',
#  'nan',
#  'nan',
#  'nan',
#  'nan',
#  'nan',
#  'nan',
#  'nan',
#  'nan',
#  'nan',
#  'nan',
#  'nan',
#  'nan',
#  'nan',
#  'nan',
#  'nan',
#  'nan',
#  'nan',
#  'nan',
#  'nan',
#  'nan',
#  'nan',
#  'nan',
#  'nan',
#  'nan',
#  'nan',
#  'nan',
#  'nan',
#  'nan',
#  'ablaz',
#  'ablaz',
#  'ablaz',
#  'ablaz',
#  'ablaz',
#  'ablaz',
#  'ablaz',
#  'ablaz',
#  'ablaz',
#  'ablaz',
#  'ablaz',
#  'ablaz',
#  'ablaz',
#  'ablaz',
#  'ablaz',
#  'ablaz',
#  'ablaz',
#  'ablaz',
#  'ablaz',
#  'ablaz',
#  'ablaz',
#  'ablaz',
#  'ablaz',
#  'ablaz',
#  'ablaz',
#  'ablaz',
#  'ablaz',
#  'ablaz',
#  'ablaz',
#  'ablaz',
#  'ablaz',
#  'ablaz',
#  'ablaz',
#  'ablaz',
#  'ablaz',
#  'ablaz',
#  'accid',
#  'accid',
#  'accid',
#  'accid',
#  'accid',
#  'accid',
#  'accid',
#  'accid',
#  'accid',
#  'accid',
#  'accid',
#  'accid',
#  'accid',
#  'accid',
#  'accid',
#  'accid',
#  'accid',
#  'accid',
#  'accid',
#  'accid',
#  'accid',
#  'accid',
#  'accid',
#  'accid',
#  'accid',
#  'accid',
#  'accid',
#  'accid',
#  'accid',
#  'accid',
#  'accid',
#  'accid',
#  'accid',
#  'accid',
#  'accid',
#  'aftershock',
#  'aftershock',
#  'aftershock',
#  'aftershock',
#  'aftershock',
#  'aftershock',
#  'aftershock',
#  'aftershock',
#  'aftershock',
#  'aftershock',
#  'aftershock',
#  'aftershock',
#  'aftershock',
#  'aftershock',
#  'aftershock',
#  'aftershock',
#  'aftershock',
#  'aftershock',
#  'aftershock',
#  'aftershock',
#  'aftershock',
#  'aftershock',
#  'aftershock',
#  'aftershock',
#  'aftershock',
#  'aftershock',
#  'aftershock',
#  'aftershock',
#  'aftershock',
#  'aftershock',
#  'aftershock',
#  'aftershock',
#  'aftershock',
#  'aftershock',
#  'airplane accid',
#  'airplane accid',
#  'airplane accid',
#  'airplane accid',
#  'airplane accid',
#  'airplane accid',
#  'airplane accid',
#  'airplane accid',
#  'airplane accid',
#  'airplane accid',
#  'airplane accid',
#  'airplane accid',
#  'airplane accid',
#  'airplane accid',
#  'airplane accid',
#  'airplane accid',
#  'airplane accid',
#  'airplane accid',
#  'airplane accid',
#  'airplane accid',
#  'airplane accid',
#  'airplane accid',
#  'airplane accid',
#  'airplane accid',
#  'airplane accid',
#  'airplane accid',
#  'airplane accid',
#  'airplane accid',
#  'airplane accid',
#  'airplane accid',
#  'airplane accid',
#  'airplane accid',
#  'airplane accid',
#  'airplane accid',
#  'airplane accid',
#  'ambul',
#  'ambul',
#  'ambul',
#  'ambul',
#  'ambul',
#  'ambul',
#  'ambul',
#  'ambul',
#  'ambul',
#  'ambul',
#  'ambul',
#  'ambul',
#  'ambul',
#  'ambul',
#  'ambul',
#  'ambul',
#  'ambul',
#  'ambul',
#  'ambul',
#  'ambul',
#  'ambul',
#  'ambul',
#  'ambul',
#  'ambul',
#  'ambul',
#  'ambul',
#  'ambul',
#  'ambul',
#  'ambul',
#  'ambul',
#  'ambul',
#  'ambul',
#  'ambul',
#  'ambul',
#  'ambul',
#  'ambul',
#  'ambul',
#  'ambul',
#  'annihil',
#  'annihil',
#  'annihil',
#  'annihil',
#  'annihil',
#  'annihil',
#  'annihil',
#  'annihil',
#  'annihil',
#  'annihil',
#  'annihil',
#  'annihil',
#  'annihil',
#  'annihil',
#  'annihil',
#  'annihil',
#  'annihil',
#  'annihil',
#  'annihil',
#  'annihil',
#  'annihil',
#  'annihil',
#  'annihil',
#  'annihil',
#  'annihil',
#  'annihil',
#  'annihil',
#  'annihil',
#  'annihil',
#  'annihil',
#  'annihil',
#  'annihil',
#  'annihil',
#  'annihil',
#  'annihil',
#  'annihil',
#  'annihil',
#  'annihil',
#  'annihil',
#  'annihil',
#  'annihil',
#  'annihil',
#  'annihil',
#  'annihil',
#  'annihil',
#  'annihil',
#  'annihil',
#  'annihil',
#  'annihil',
#  'annihil',
#  'annihil',
#  'annihil',
#  'annihil',
#  'annihil',
#  'annihil',
#  'annihil',
#  'annihil',
#  'annihil',
#  'annihil',
#  'annihil',
#  'annihil',
#  'annihil',
#  'annihil',
#  'apocalyps',
#  'apocalyps',
#  'apocalyps',
#  'apocalyps',
#  'apocalyps',
#  'apocalyps',
#  'apocalyps',
#  'apocalyps',
#  'apocalyps',
#  'apocalyps',
#  'apocalyps',
#  'apocalyps',
#  'apocalyps',
#  'apocalyps',
#  'apocalyps',
#  'apocalyps',
#  'apocalyps',
#  'apocalyps',
#  'apocalyps',
#  'apocalyps',
#  'apocalyps',
#  'apocalyps',
#  'apocalyps',
#  'apocalyps',
#  'apocalyps',
#  'apocalyps',
#  'apocalyps',
#  'apocalyps',
#  'apocalyps',
#  'apocalyps',
#  'apocalyps',
#  'apocalyps',
#  'armageddon',
#  'armageddon',
#  'armageddon',
#  'armageddon',
#  'armageddon',
#  'armageddon',
#  'armageddon',
#  'armageddon',
#  'armageddon',
#  'armageddon',
#  'armageddon',
#  'armageddon',
#  'armageddon',
#  'armageddon',
#  'armageddon',
#  'armageddon',
#  'armageddon',
#  'armageddon',
#  'armageddon',
#  'armageddon',
#  'armageddon',
#  'armageddon',
#  'armageddon',
#  'armageddon',
#  'armageddon',
#  'armageddon',
#  'armageddon',
#  'armageddon',
#  'armageddon',
#  'armageddon',
#  'armageddon',
#  'armageddon',
#  'armageddon',
#  'armageddon',
#  'armageddon',
#  'armageddon',
#  'armageddon',
#  'armageddon',
#  'armageddon',
#  'armageddon',
#  'armageddon',
#  'armageddon',
#  'armi',
#  'armi',
#  'armi',
#  'armi',
#  'armi',
#  'armi',
#  'armi',
#  'armi',
#  'armi',
#  'armi',
#  'armi',
#  'armi',
#  'armi',
#  'armi',
#  'armi',
#  'armi',
#  'armi',
#  'armi',
#  'armi',
#  'armi',
#  'armi',
#  'armi',
#  'armi',
#  'armi',
#  'armi',
#  'armi',
#  'armi',
#  'armi',
#  'armi',
#  'armi',
#  'armi',
#  'armi',
#  'armi',
#  'armi',
#  'arson',
#  'arson',
#  'arson',
#  'arson',
#  'arson',
#  'arson',
#  'arson',
#  'arson',
#  'arson',
#  'arson',
#  'arson',
#  'arson',
#  'arson',
#  'arson',
#  'arson',
#  'arson',
#  'arson',
#  'arson',
#  'arson',
#  'arson',
#  'arson',
#  'arson',
#  'arson',
#  'arson',
#  'arson',
#  'arson',
#  'arson',
#  'arson',
#  'arson',
#  'arson',
#  'arson',
#  'arson',
#  'arsonist',
#  'arsonist',
#  'arsonist',
#  'arsonist',
#  'arsonist',
#  'arsonist',
#  'arsonist',
#  'arsonist',
#  'arsonist',
#  'arsonist',
#  'arsonist',
#  'arsonist',
#  'arsonist',
#  'arsonist',
#  'arsonist',
#  'arsonist',
#  'arsonist',
#  'arsonist',
#  'arsonist',
#  'arsonist',
#  'arsonist',
#  'arsonist',
#  'arsonist',
#  'arsonist',
#  'arsonist',
#  'arsonist',
#  'arsonist',
#  'arsonist',
#  'arsonist',
#  'arsonist',
#  'arsonist',
#  'arsonist',
#  'arsonist',
#  'arsonist',
#  'attack',
#  'attack',
#  'attack',
#  'attack',
#  'attack',
#  'attack',
#  'attack',
#  'attack',
#  'attack',
#  'attack',
#  'attack',
#  'attack',
#  'attack',
#  'attack',
#  'attack',
#  'attack',
#  'attack',
#  'attack',
#  'attack',
#  'attack',
#  'attack',
#  'attack',
#  'attack',
#  'attack',
#  'attack',
#  'attack',
#  'attack',
#  'attack',
#  'attack',
#  'attack',
#  'attack',
#  'attack',
#  'attack',
#  'attack',
#  'attack',
#  'attack',
#  'attack',
#  'attack',
#  'attack',
#  'attack',
#  'attack',
#  'attack',
#  'attack',
#  'attack',
#  'attack',
#  'attack',
#  'attack',
#  'attack',
#  'attack',
#  'attack',
#  'attack',
#  'attack',
#  'attack',
#  'attack',
#  'attack',
#  'attack',
#  'attack',
#  'attack',
#  'attack',
#  'attack',
#  'attack',
#  'attack',
#  'attack',
#  'attack',
#  'attack',
#  'attack',
#  'attack',
#  'attack',
#  'attack',
#  'attack',
#  'attack',
#  'avalanch',
#  'avalanch',
#  'avalanch',
#  'avalanch',
#  'avalanch',
#  'avalanch',
#  'avalanch',
#  'avalanch',
#  'avalanch',
#  'avalanch',
#  'avalanch',
#  'avalanch',
#  'avalanch',
#  'avalanch',
#  'avalanch',
#  'avalanch',
#  'avalanch',
#  'avalanch',
#  'avalanch',
#  'avalanch',
#  'avalanch',
#  'avalanch',
#  'avalanch',
#  'avalanch',
#  'avalanch',
#  'avalanch',
#  'avalanch',
#  'avalanch',
#  'avalanch',
#  'avalanch',
#  'battl',
#  'battl',
#  'battl',
#  'battl',
#  'battl',
#  'battl',
#  'battl',
#  'battl',
#  'battl',
#  'battl',
#  'battl',
#  'battl',
#  'battl',
#  'battl',
#  'battl',
#  'battl',
#  'battl',
#  'battl',
#  'battl',
#  'battl',
#  'battl',
#  'battl',
#  'battl',
#  'battl',
#  'battl',
#  'battl',
#  'bioterror',
#  'bioterror',
#  'bioterror',
#  'bioterror',
#  'bioterror',
#  'bioterror',
#  'bioterror',
#  'bioterror',
#  'bioterror',
#  'bioterror',
#  'bioterror',
#  'bioterror',
#  'bioterror',
#  'bioterror',
#  'bioterror',
#  'bioterror',
#  'bioterror',
#  'bioterror',
#  'bioterror',
#  'bioterror',
#  'bioterror',
#  'bioterror',
#  'bioterror',
#  'bioterror',
#  'bioterror',
#  'bioterror',
#  'bioterror',
#  'bioterror',
#  'bioterror',
#  'bioterror',
#  'bioterror',
#  'bioterror',
#  'bioterror',
#  'bioterror',
#  'bioterror',
#  'bioterror',
#  'bioterror',
#  'bioterror',
#  'bioterror',
#  'bioterror',
#  'bioterror',
#  'bioterror',
#  'bioterror',
#  'bioterror',
#  'bioterror',
#  'bioterror',
#  'bioterror',
#  'bioterror',
#  'bioterror',
#  'bioterror',
#  'bioterror',
#  'bioterror',
#  'bioterror',
#  'bioterror',
#  'bioterror',
#  'bioterror',
#  'bioterror',
#  'bioterror',
#  'bioterror',
#  'bioterror',
#  'bioterror',
#  'bioterror',
#  'bioterror',
#  'bioterror',
#  'bioterror',
#  'bioterror',
#  'bioterror',
#  'blaze',
#  'blaze',
#  'blaze',
#  'blaze',
#  'blaze',
#  'blaze',
#  'blaze',
#  'blaze',
#  'blaze',
#  'blaze',
#  'blaze',
#  'blaze',
#  'blaze',
#  'blaze',
#  'blaze',
#  'blaze',
#  'blaze',
#  'blaze',
#  'blaze',
#  'blaze',
#  'blaze',
#  'blaze',
#  'blaze',
#  'blaze',
#  'blaze',
#  'blaze',
#  'blaze',
#  'blaze',
#  'blaze',
#  'blaze',
#  'blaze',
#  'blaze',
#  'blaze',
#  'blaze',
#  'blaze',
#  'blaze',
#  'blaze',
#  'blaze',
#  'blaze',
#  'blaze',
#  'blaze',
#  'blaze',
#  'blaze',
#  'blaze',
#  'blaze',
#  'blaze',
#  'blaze',
#  'blaze',
#  'blaze',
#  'blaze',
#  'blaze',
#  'blaze',
#  'blaze',
#  'blaze',
#  'blaze',
#  'blaze',
#  'blaze',
#  'blaze',
#  'blaze',
#  'blaze',
#  'blaze',
#  'blaze',
#  'blaze',
#  'blaze',
#  'blaze',
#  'blaze',
#  'blaze',
#  'blaze',
#  'blaze',
#  'blaze',
#  'blaze',
#  'blaze',
#  'bleed',
#  'bleed',
#  'bleed',
#  'bleed',
#  'bleed',
#  'bleed',
#  'bleed',
#  'bleed',
#  'bleed',
#  'bleed',
#  'bleed',
#  'bleed',
#  'bleed',
#  'bleed',
#  'bleed',
#  'bleed',
#  'bleed',
#  'bleed',
#  'bleed',
#  'bleed',
#  'bleed',
#  'bleed',
#  'bleed',
#  'bleed',
#  'bleed',
#  'bleed',
#  'bleed',
#  'bleed',
#  'bleed',
#  'bleed',
#  'bleed',
#  'bleed',
#  'bleed',
#  'bleed',
#  'bleed',
#  'blew up',
#  'blew up',
#  'blew up',
#  'blew up',
#  'blew up',
#  'blew up',
#  'blew up',
#  'blew up',
#  'blew up',
#  'blew up',
#  'blew up',
#  'blew up',
#  'blew up',
#  'blew up',
#  'blew up',
#  'blew up',
#  'blew up',
#  'blew up',
#  'blew up',
#  'blew up',
#  'blew up',
#  'blew up',
#  'blew up',
#  'blew up',
#  'blew up',
#  'blew up',
#  'blew up',
#  'blew up',
#  'blew up',
#  'blew up',
#  'blew up',
#  'blew up',
#  'blew up',
#  'blight',
#  'blight',
#  'blight',
#  'blight',
#  'blight',
#  'blight',
#  'blight',
#  'blight',
#  'blight',
#  'blight',
#  'blight',
#  'blight',
#  'blight',
#  'blight',
#  'blight',
#  'blight',
#  'blight',
#  'blight',
#  'blight',
#  'blight',
#  'blight',
#  'blight',
#  'blight',
#  'blight',
#  'blight',
#  'blight',
#  'blight',
#  'blight',
#  'blight',
#  'blight',
#  'blight',
#  'blight',
#  'blizzard',
#  'blizzard',
#  'blizzard',
#  'blizzard',
#  'blizzard',
#  'blizzard',
#  'blizzard',
#  'blizzard',
#  'blizzard',
#  'blizzard',
#  'blizzard',
#  'blizzard',
#  'blizzard',
#  'blizzard',
#  'blizzard',
#  'blizzard',
#  'blizzard',
#  'blizzard',
#  'blizzard',
#  'blizzard',
#  'blizzard',
#  'blizzard',
#  'blizzard',
#  'blizzard',
#  'blizzard',
#  'blizzard',
#  'blizzard',
#  'blizzard',
#  'blizzard',
#  'blizzard',
#  'blizzard',
#  'blizzard',
#  'blizzard',
#  'blizzard',
#  'blizzard',
#  'blizzard',
#  'blizzard',
#  'blood',
#  'blood',
#  'blood',
#  'blood',
#  'blood',
#  'blood',
#  'blood',
#  'blood',
#  'blood',
#  'blood',
#  'blood',
#  'blood',
#  'blood',
#  'blood',
#  'blood',
#  'blood',
#  'blood',
#  'blood',
#  'blood',
#  'blood',
#  'blood',
#  'blood',
#  'blood',
#  'blood',
#  'blood',
#  'blood',
#  'blood',
#  'blood',
#  'blood',
#  'blood',
#  'blood',
#  'blood',
#  'blood',
#  'blood',
#  'blood',
#  'bloodi',
#  'bloodi',
#  'bloodi',
#  'bloodi',
#  'bloodi',
#  'bloodi',
#  'bloodi',
#  'bloodi',
#  'bloodi',
#  'bloodi',
#  'bloodi',
#  'bloodi',
#  'bloodi',
#  'bloodi',
#  'bloodi',
#  'bloodi',
#  'bloodi',
#  'bloodi',
#  'bloodi',
#  'bloodi',
#  'bloodi',
#  'bloodi',
#  'bloodi',
#  'bloodi',
#  'bloodi',
#  'bloodi',
#  'bloodi',
#  'bloodi',
#  'bloodi',
#  'bloodi',
#  'bloodi',
#  'bloodi',
#  'bloodi',
#  'bloodi',
#  'bloodi',
#  'blown up',
#  'blown up',
#  'blown up',
#  'blown up',
#  'blown up',
#  'blown up',
#  'blown up',
#  'blown up',
#  'blown up',
#  'blown up',
#  'blown up',
#  'blown up',
#  'blown up',
#  'blown up',
#  'blown up',
#  'blown up',
#  'blown up',
#  'blown up',
#  'blown up',
#  'blown up',
#  'blown up',
#  'blown up',
#  'blown up',
#  'blown up',
#  'blown up',
#  'blown up',
#  'blown up',
#  'blown up',
#  'blown up',
#  'blown up',
#  'blown up',
#  'blown up',
#  'blown up',
#  'body bag',
#  'body bag',
#  'body bag',
#  'body bag',
#  'body bag',
#  'body bag',
#  'body bag',
#  'body bag',
#  'body bag',
#  'body bag',
#  'body bag',
#  'body bag',
#  'body bag',
#  'body bag',
#  'body bag',
#  'body bag',
#  'body bag',
#  'body bag',
#  'body bag',
#  'body bag',
#  'body bag',
#  'body bag',
#  'body bag',
#  'body bag',
#  'body bag',
#  'body bag',
#  'body bag',
#  'body bag',
#  'body bag',
#  'body bag',
#  'body bag',
#  'body bag',
#  'body bag',
#  'body bag',
#  'body bag',
#  'body bag',
#  'body bag',
#  'body bag',
#  'body bag',
#  'body bag',
#  'body bag',
#  'body bag',
#  'body bag',
#  'body bag',
#  'body bag',
#  'body bag',
#  'body bag',
#  'body bag',
#  ...]

# %%
#We store de unique keywords to use them for the rows without keywords
unique_keywords = pd.unique(lista)

# %%
train['keyword'] = lista

# %%
train[train['keyword'] == "nan"]['text']
# Out:
# 0       Our Deeds are the Reason of this #earthquake M...
# 1                  Forest fire near La Ronge Sask. Canada
# 2       All residents asked to 'shelter in place' are ...
# 3       13,000 people receive #wildfires evacuation or...
# 4       Just got sent this photo from Ruby #Alaska as ...
#                               ...
# 7608    Two giant cranes holding a bridge collapse int...
# 7609    @aria_ahrary @TheTawniest The out of control w...
# 7610    M1.94 [01:04 UTC]?5km S of Volcano Hawaii. htt...
# 7611    Police investigating after an e-bike collided ...
# 7612    The Latest: More Homes Razed by Northern Calif...
# Name: text, Length: 61, dtype: object

# %%
train[['text','id']]
# Out:
#                                                    text     id
# 0     Our Deeds are the Reason of this #earthquake M...      1
# 1                Forest fire near La Ronge Sask. Canada      4
# 2     All residents asked to 'shelter in place' are ...      5
# 3     13,000 people receive #wildfires evacuation or...      6
# 4     Just got sent this photo from Ruby #Alaska as ...      7
# ...                                                 ...    ...
# 7608  Two giant cranes holding a bridge collapse int...  10869
# 7609  @aria_ahrary @TheTawniest The out of control w...  10870
# 7610  M1.94 [01:04 UTC]?5km S of Volcano Hawaii. htt...  10871
# 7611  Police investigating after an e-bike collided ...  10872
# 7612  The Latest: More Homes Razed by Northern Calif...  10873
#
# [7613 rows x 2 columns]

# %%
i=0
words = []
for sentence in train[train['keyword'] == "nan"]['text']:
    for key in unique_keywords:
        if key in sentence:
            words.append(key)
    if len(words)+1<i:
        words.append("nan")
    i+=1

# %%
len(lista)
# Out:
# 7613

# %%
a = 0
i = 0
indexes = []
for word in words:
    if word[1] == a:
        indexes.append(i)
    a = word[1]
    i+=1

# %%
for index in sorted(indexes, reverse=True):
    del words[index]

# %%
words
# Out:
# ['earthquak',
#  'fire',
#  'evacu',
#  'fire',
#  'smoke',
#  'wildfir',
#  'flood',
#  'fire',
#  'emerg',
#  'evacu',
#  'tornado',
#  'heat wav',
#  'flood',
#  'crash',
#  'nan',
#  'bomb',
#  'deton',
#  'suicide bomb',
#  'explod',
#  'nan',
#  'attack',
#  'earthquak',
#  'bomb',
#  'deton',
#  'explos',
#  'suicide bomb',
#  'loud bang',
#  'explod',
#  'scream',
#  'storm',
#  'trauma',
#  'debri',
#  'oil spil',
#  'tornado',
#  'quarantin',
#  'evacu',
#  'bomb',
#  'evacu',
#  'bomb',
#  'storm',
#  'bridge collaps',
#  'collaps',
#  'fire',
#  'troubl',
#  'wild fir',
#  'collid',
#  'injur',
#  'threat',
#  'fire']

# %%
i = 0
j = 0
for word in lista:
    if word == 'nan':
        lista[j] = words[i]
        i += 1
    j+=1
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In [24], line 5
#       3 for word in lista:
#       4     if word == 'nan':
# ----> 5         lista[j] = words[i]
#       6         i += 1
#       7     j+=1
#
# IndexError: list index out of range

# %%
len(words)
# Out:
# 49

# %%
train['keyword'] = lista

# %%
words

# %%
train[train['keyword'] == "nan"]

# %%
train.head(50)

# %% [markdown]
# ## Rallado

# %%
str(train['keyword'][0])
# Out:
# 'nan'

# %%
lista = []
i = 0
for keyword,text in zip(train['keyword'],train['text']):
    if str(keyword) == 'nan':
        keyword = str(keyword).lower()
        for keyword in train['keyword']:
            keyword = str(keyword).lower()
            if keyword in text.lower():
                if len(lista) < i+1:
                    lista.append(keyword)
        if len(lista) < i+1:
                    lista.append('nan')
    else: 
        lista.append(keyword)
    i+=1

# %%
len(lista)
# Out:
# 7613

# %%
train['keyword'] = lista

# %%
#Lets lemmatize the keywords
lista = []
i=0
ps = PorterStemmer()
for keyword in train['keyword']:
    lista.append(ps.stem(str(keyword).replace("%20"," ")))

# %%
train['keyword'] = lista

# %%
train
# Out:
#          id    keyword location  \
# 0         1  earthquak      NaN
# 1         4       fire      NaN
# 2         5      evacu      NaN
# 3         6      evacu      NaN
# 4         7       fire      NaN
# ...     ...        ...      ...
# 7608  10869    collaps      NaN
# 7609  10870       fire      NaN
# 7610  10871    volcano      NaN
# 7611  10872     collid      NaN
# 7612  10873       fire      NaN
#
#                                                    text  target
# 0     Our Deeds are the Reason of this #earthquake M...       1
# 1                Forest fire near La Ronge Sask. Canada       1
# 2     All residents asked to 'shelter in place' are ...       1
# 3     13,000 people receive #wildfires evacuation or...       1
# 4     Just got sent this photo from Ruby #Alaska as ...       1
# ...                                                 ...     ...
# 7608  Two giant cranes holding a bridge collapse int...       1
# 7609  @aria_ahrary @TheTawniest The out of control w...       1
# 7610  M1.94 [01:04 UTC]?5km S of Volcano Hawaii. htt...       1
# 7611  Police investigating after an e-bike collided ...       1
# 7612  The Latest: More Homes Razed by Northern Calif...       1
#
# [7613 rows x 5 columns]

# %%
text_list = []
dic = {"@":"", ":":"", "#":"",".":"","?":"","[":"","]":"","/":" ","(":"",")":"","_":"","-":"","!":"","¡":"","'":"","|":"","\n":" ","&":""}
for sentence in train['text']:
    new_sentence = sentence.lower()
    for i, j in dic.items():
        new_sentence = new_sentence.replace(i, j)
    text_list.append(new_sentence.strip())

# %%
text_list
# Out:
# ['our deeds are the reason of this earthquake may allah forgive us all',
#  'forest fire near la ronge sask canada',
#  'all residents asked to shelter in place are being notified by officers no other evacuation or shelter in place orders are expected',
#  '13,000 people receive wildfires evacuation orders in california',
#  'just got sent this photo from ruby alaska as smoke from wildfires pours into a school',
#  'rockyfire update => california hwy 20 closed in both directions due to lake county fire  cafire wildfires',
#  'flood disaster heavy rain causes flash flooding of streets in manitou, colorado springs areas',
#  'im on top of the hill and i can see a fire in the woods',
#  'theres an emergency evacuation happening now in the building across the street',
#  'im afraid that the tornado is coming to our area',
#  'three people died from the heat wave so far',
#  'haha south tampa is getting flooded hah wait a second i live in south tampa what am i gonna do what am i gonna do fvck flooding',
#  'raining flooding florida tampabay tampa 18 or 19 days ive lost count',
#  'flood in bago myanmar we arrived bago',
#  'damage to school bus on 80 in multi car crash breaking',
#  'whats up man',
#  'i love fruits',
#  'summer is lovely',
#  'my car is so fast',
#  'what a goooooooaaaaaal',
#  'this is ridiculous',
#  'london is cool ;',
#  'love skiing',
#  'what a wonderful day',
#  'looooool',
#  'no wayi cant eat that shit',
#  'was in nyc last week',
#  'love my girlfriend',
#  'cooool',
#  'do you like pasta',
#  'the end',
#  'bbcmtd wholesale markets ablaze http  tco lhyxeohy6c',
#  'we always try to bring the heavy metal rt http  tco yao1e0xngw',
#  'africanbaze breaking newsnigeria flag set ablaze in aba http  tco 2nndbgwyei',
#  'crying out for more set me ablaze',
#  'on plus side look at the sky last night it was ablaze http  tco qqsmshaj3n',
#  'phdsquares mufc theyve built so much hype around new acquisitions but i doubt they will set the epl ablaze this season',
#  'inec office in abia set ablaze  http  tco 3imaomknna',
#  'barbados bridgetown jamaica \x89ûò two cars set ablaze santa cruz \x89ûó head of the st elizabeth police superintende  http  tco wdueaj8q4j',
#  'ablaze for you lord d',
#  'check these out http  tco roi2nsmejj http  tco 3tj8zjin21 http  tco yduixefipe http  tco lxtjc87kls nsfw',
#  'on the outside youre ablaze and alive but youre dead inside',
#  'had an awesome time visiting the cfc head office the ancop site and ablaze thanks to tita vida for taking care of us',
#  'soooo pumped for ablaze  southridgelife',
#  'i wanted to set chicago ablaze with my preaching but not my hotel http  tco o9qknbfofx',
#  'i gained 3 followers in the last week you know your stats and grow with http  tco tiyulif5c6',
#  'how the west was burned thousands of wildfires ablaze in california alone http  tco vl5tbr3wbr',
#  'building the perfect tracklist to life leave the streets ablaze',
#  'check these out http  tco roi2nsmejj http  tco 3tj8zjin21 http  tco yduixefipe http  tco lxtjc87kls nsfw',
#  'first night with retainers in its quite weird better get used to it; i have to wear them every single night for the next year at least',
#  'deputies man shot before brighton home set ablaze http  tco gwnrhmso8k',
#  'man wife get six years jail for setting ablaze niece http  tco ev1ahoucza',
#  'santa cruz \x89ûó head of the st elizabeth police superintendent lanford salmon has r   http  tco vplr5hka2u http  tco sxhw2tnnlf',
#  'police arsonist deliberately set black church in north carolinaåêablaze http  tco pcxarbh9an',
#  'noches elbestia alexissanchez happy to see my teammates and training hard  goodnight gunners http  tco uc4j4jhvgr',
#  'kurds trampling on turkmen flag later set it ablaze while others vandalized offices of turkmen front in diyala http  tco 4izfdyc3cg',
#  'truck ablaze  r21 voortrekker ave outside or tambo intl cargo section http  tco 8kscqkfkkf',
#  'set our hearts ablaze and every city was a gift and every skyline was like a kiss upon the lips \x89û https  tco cyompz1a0z',
#  'they sky was ablaze tonight in los angeles im expecting ig and fb to be filled with sunset shots if i know my peeps',
#  'how the west was burned thousands of wildfires ablaze in california alone http  tco icsjgz9te1 climate energy http  tco 9fxmn0l0bd',
#  'revel in yours wmv videos by means of mac farewell ablaze wmv en route to dvd gtxrwm',
#  'progressive greetings  in about a month students would have set their pens ablaze in the torch publications http  tco 9fxpixqujt',
#  'rene ablaze amp; jacinta  secret 2k13 fallen skies edit  mar 30 2013  https  tco 7mlmsuzv1z',
#  'navista7 steve these fires out here are something else california is a tinderbox  and this clown was setting my hood ablaze news24680',
#  'nowplaying rene ablaze amp; ian buff  magnitude http  tco av2jsjfftc  edm',
#  'nxwestmidlands huge fire at wholesale markets ablaze http  tco rwzbfvnxer',
#  'ablaze what time does your talk go until i dont know if i can make it due to work',
#  'i cant have kids cuz i got in a bicycle accident amp; split my testicles its impossible for me to have kids michael you are the father',
#  'accident on i24 w nashvilletraffic traffic moving 8m slower than usual https  tco 0ghk693egj',
#  'accident center lane blocked in santaclara on us101 nb before great america pkwy bayarea traffic http  tco pmlohzurwr',
#  'http  tco gkye6gjtk5 had a personalinjury accident this summer read our advice amp; see how a solicitor can help otleyhour',
#  'stlouis caraccidentlawyer speeding among top causes of teen accidents https  tco k4zomof319 https  tco s2kxvm0cba car accident tee\x89û',
#  'reported motor vehicle accident in curry on herman rd near stephenson involving an overturned vehicle please use http  tco ybjezkurw1',
#  'bigrigradio live accident awareness',
#  'i77 mile marker 31 south mooresville  iredell vehicle accident ramp closed at 8 6 118 pm',
#  'rt sleepjunkies sleeping pills double your risk of a car accident http  tco 7s9nm1fict',
#  'by accident they knew what was gon happen https  tco ysxun5vceh',
#  'traffic accident n cabrillo hwy magellan av mir 08 06 15 110358',
#  'i77 mile marker 31 to 40 south mooresville  iredell vehicle accident congestion at 8 6 118 pm',
#  'the pastor was not in the scene of the accidentwho was the owner of the range rover',
#  'mom we didnt get home as fast as we wished  me why is that mom there was an accident and some truck spilt mayonnaise all over',
#  'i was in a horrible car accident this past sunday im finally able to get around thank you god',
#  'can wait to see how pissed donnie is when i tell him i was in another accident',
#  'truckcrash overturns on fortworth interstate http  tco rs22lj4qfp click here if youve been in a crashgt;http  tco ld0uniyw4k',
#  'accident in ashville on us 23 sb before sr 752 traffic http  tco hylmo0wgfi',
#  'carolina accident motorcyclist dies in i540 crash with car that crossed median a motorcycle rider traveling http  tco p18lzrlmy6',
#  'fyi cadfyi ;accident property damage;nhs;999 piner rd horndale dr',
#  'rt naayf first accident in years turning onto chandanee magu from near mma taxi rammed into me while i was halfway turned everyone conf\x89û',
#  'accident left lane blocked in manchester on rt 293 nb before eddy rd stop and go traffic back to nh3a delay of 4 mins traffic',
#  ';accident property damage; piner rd horndale dr',
#  'it was an accident http  tco oia5fxi4gm',
#  'fyi cadfyi ;accident property damage;wpd;1600 s 17th st',
#  '8 6 2015209 pm traffic accident no injury at 2781 willis foreman rd http  tco vckit6edev',
#  'aashiqui actress anu aggarwal on her nearfatal accident http  tco 6otfp31lqw',
#  'suffield alberta accident https  tco bptmlf4p10',
#  '9 mile backup on i77 southaccident blocking the right 2 lanes at exit 31 langtree rdconsider nc 115 or nc 150 to nc 16 as alternate',
#  'has an accident changed your life we will help you determine options that can financially support life care plans and ongoing treatment',
#  'breaking there was a deadly motorcycle car accident that happened to hagerstown today ill have more details at 5 your4state whag',
#  'flowri were you marinading it or was it an accident',
#  'only had a car for not even a week and got in a fucking car accident  mfs cant fucking drive',
#  'norwaymfa bahrain police had previously died in a road accident they were not killed by explosion https  tco gfjfgtodad',
#  'i still have not heard church leaders of kenya coming forward to comment on the accident issue and disciplinary measuresarrestpastornganga',
#  'aftershockdelo scuf ps live and the game cya',
#  'the man who can drive himself further once the effort gets painful is the man who will win  roger bannister',
#  '320 ir icemoon aftershock  http  tco ynxnvvkcda  djicemoon  dubstep trapmusic dnb edm dance ices\x89û http  tco weqpesenku',
#  'there is no victory at bargain basement prices dwight david eisenhower',
#  '320 ir icemoon aftershock  http  tco vam5podgyw  djicemoon  dubstep trapmusic dnb edm dance ices\x89û http  tco zevakjapcz',
#  'nobody remembers who came in second charles schulz',
#  'aftershockdelo im speaking from someone that is using a scuf on xb1 most of them people will end up getting on for ps also',
#  'the harder the conflict the more glorious the triumph thomas paine',
#  'growingupspoiled going clay pigeon shooting and crying because of the aftershock',
#  'so i guess no one actually wants any free aftershock tc',
#  'aftershock was the most terrifying best roller coaster ive ever been on *disclaimer* ive been on very few',
#  'aftershock https  tco xmwodfmtui',
#  '320 ir icemoon aftershock  http  tco m4jdzmgjow  djicemoon  dubstep trapmusic dnb edm dance ices\x89û http  tco n0uhasfkbv',
#  '320 ir icemoon aftershock  http  tco vam5podgyw  djicemoon  dubstep trapmusic dnb edm dance ices\x89û http  tco zevakjapcz',
#  '320 ir icemoon aftershock  http  tco e14epzhoth  djicemoon  dubstep trapmusic dnb edm dance ices\x89û http  tco 22a9d5do6q',
#  'kjfordays im seeing them and issues at aftershock',
#  '320 ir icemoon aftershock  http  tco thyzomvwu0  djicemoon  dubstep trapmusic dnb edm dance ices\x89û http  tco 83joo0xk29',
#  '320 ir icemoon aftershock  http  tco thyzomvwu0  djicemoon  dubstep trapmusic dnb edm dance ices\x89û http  tco 83joo0xk29',
#  'wisdomwed bonus  5 minute daily habits that could really improve your life how many do you already do lifehacks http  tco tbm9fqb8cw',
#  'aftershock protect yourself and profit in the next global financial meltdown by david wiedemer http http  tco wztz4hgmvq',
#  'that moment when you get on a scary roller coaster and the guy behind you is just screaming bloody murder  silverwood aftershock',
#  'aftershock \x89ã¢ 2010 full\x89ã¢ streaming  youtube http  tco vve3usesgf',
#  'gt;gt; $15 aftershock  protect yourself and profit in the next global financial book http  tco f6ntuc734z esquireattire',
#  'sometimes you face difficulties not because youre doing something wrong but because youre doing something right  joel osteen',
#  'the only thing that stands between you and your dream is the will to try and the belief that it is actually possible  joel brown',
#  'praise god that we have ministry that tells it like it is now wdyouth biblestudy https  tco ujk0e5gbcc',
#  'remembering that you are going to die is the best way i know to avoid the trap of thinking you have something to lose \x89ûò steve jobs',
#  'tried orange aftershock today my life will never be the same',
#  'onfireanders i love you bb',
#  'aftershock https  tco jv8ppkhjy7',
#  'aftershock back to school kick off was great i want to thank everyone for making it possible what a great night',
#  'people who say it cannot be done should not interrupt those who are doing it \x89ûò george bernard shaw',
#  'the first man gets the oyster the second man gets the shell andrew carnegie',
#  'anyone need a p u tonight i play hybrid slayer ps4 eu hmu cod8sandscrims empirikgaming codawscrims 4tpkotc 4tpfa aftershockorg',
#  'experts in france begin examining airplane debris found on reunion island french air accident experts o http  tco yvvpznzmxg news',
#  'strict liability in the context of an airplane accident pilot error is a common component of most aviation cr http  tco 6cz3bohrd4',
#  'crobscarla your lifetime odds of dying from an airplane accident are 1 in 8015',
#  'experts in france begin examining airplane debris found on reunion island french air accident experts on wedn http  tco bkpfpogysi',
#  'alexalltimelow awwww theyre on an airplane accident and theyre gonna die what a cuties  good job',
#  'family members of osama bin laden have died in an airplane accident how ironic  mhmmm gov shit i suspect',
#  'man goes into airplane engine accident http  tco tyjxrfd3st via youtube',
#  'horrible accident  man died in wings of airplane 29072015 http  tco i7kztevb2v',
#  'a cessna airplane accident in ocampo coahuila mexico on july 29 2015 killed four men including a state of coahuila government official',
#  'horrible accident man died in wings airplane 29072015 watchthevideo http  tco p64xrvgjik',
#  'experts in france begin examining airplane debris found on reunion island http  tco lsmx2vwr3j french air accident experts on wednesday\x89û',
#  'experts in france begin examining airplane debris found on reunion island french air accident experts on wednesday began examining t',
#  'kca votejkt48id mbataweel rip binladen family members who killed in an airplanes accident',
#  'i almost sent my coworker nudes on accident thank god for airplane mode',
#  'mickinyman theatlantic that or they might be killed in an airplane accident in the night a car wreck politics at its best',
#  'experts in france begin examining airplane debris found on reunion island french air accident experts on http  tco tagzbcxfj0 mlb',
#  'this is unbelievably insane man airport airplane aircraft aeroplane runway accident freaky\x89û https  tco cezhq7czll',
#  'horrible accident   man died in wings of airplaneåê29072015 http  tco wq3wjsgphl',
#  'horrible accident man died in wings of airplane 29072015 http  tco tfcdronra6',
#  'usama bin ladins family dead in airplane crash naturally no accident',
#  'pilot dies in plane crash at car festival https  tco kq9ae6ap2b via youtube crash aircraft airplane pilot death accident carfest',
#  'strict liability in the context of an airplane accident  http  tco gibyqhhkpk',
#  'dtn brazil experts in france begin examining airplane debris found on reunion island french air accident exp http  tco m9ig3wq8lq',
#  'experts in france begin examining airplane debris found on reunion island french air accident experts on wedn http  tco v4smaeslk5',
#  'horrible accident man died in wings of \x89ûïairplane\x89û\x9d 29072015 wtf you can\x89ûªt believe your eyes \x89ûò http  tco 6ffylajwps',
#  '+ nicole fletcher one of a victim of crashed airplane few times ago   the accident left a little bit trauma for her although shes   +',
#  'omg horrible accident man died in wings of airplane http  tco xdxdprcpns',
#  'omg i dont believe this rip bro airplane accident jetengine turbojet boing g90 http  tco kxxnszp6nk',
#  'experts in france begin examining airplane debris found on reunion island french air accident experts on wednesday began examining t',
#  'i had a airplane accident',
#  'my phone looks like it was in a car ship airplane accident terrible',
#  'statistically im at more of risk of getting killed by a cop than i am of dying in an airplane accident',
#  'airplane crashes on house in colombia 12 people die in accident https  tco zhjlflbhzl',
#  'the shooting or the airplane accident  https  tco iecc1jdoub',
#  'could a drone cause an airplane accident pilots worried about use of drones esp in close vicinity of airports http  tco kz35rgngjf',
#  'early wake up call from my sister begging me to come over amp; ride w her in the ambulance to the hospital rodkiai',
#  'http  tco ay6zzcupnz twelve feared killed in pakistani air ambulance helicopter crash http  tco sc9dns41mc',
#  'two air ambulances on scene of serious crash between two cars and lorry in   http  tco 9pfeaqeski http  tco fntg70rnkx  emsne\x89û',
#  'twelve feared killed in pakistani air ambulance helicopter crash  reuters http  tco mdnugvubwn yugvani',
#  'leading emergency services boss welcomes new ambulance charity http  tco mj2jq2psv6',
#  'anyone travelling aberystwythshrewsbury right now theres been an incident services at a halt just outside shrews ambulance on scene',
#  'twelve feared killed in pakistani air ambulance helicopter crash http  tco xum8ylcb4q',
#  'ambulance sprinter automatic frontline vehicle choice of 14 lez compliant  ebay http  tco 4evttqpeia',
#  'new nanotech device will be able to target and destroy blood clots http  tco hfy5v3slbb',
#  '20skyhawkmm20 traplord29 fredosantana300 lilreese300 it was hella crazy 3 fights an ambulance and a couple mosh pits',
#  'if i get run over by an ambulance am i lucky justsaying randomthought',
#  'news twelve feared killed in pakistani air ambulance helicopter crash http  tco bfes5twbzt tilnow dna',
#  'http  tco 7xglah10zl twelve feared killed in pakistani air ambulance helicopter crash http  tco thmblaatzp',
#  'tanslash waiting for an ambulance',
#  'fouseytube you ok need a ambulance hahahah that was good http  tco zsberqnn9n',
#  'ambulance sprinter automatic frontline vehicle choice of 14 lez compliant  ebay http  tco q8ivrzojzv',
#  'pakistan air ambulance helicopter crash kills nine http  tco 8e7ry8ebmf',
#  'thenissonian rejectdcartoons nissan are you ok do you need medical assistance i can call an ambulance if you need me to',
#  'ems1 ny emts petition for $17 per hour \x89û÷minimum wage\x89ûª http  tco 4oa6swlxmr ems paramedics ambulance',
#  'http  tco fcqmkffflw twelve feared killed in pakistani air ambulance helicopter crash http  tco vayaymbngu',
#  'twelve feared killed in pakistani air ambulance helicopter crash http  tco 3brme6sn4t',
#  'ambulance sprinter automatic frontline vehicle choice of 14 lez compliant  ebay http  tco ujrx9kgawp',
#  'ambulance sprinter automatic frontline vehicle choice of 14 lez compliant  ebay http  tco kp2lf4aute',
#  'kiwikaryn check out whats in my parking lot he said that until last year it was an ambulance in st johns http  tco hpvodud7ip',
#  'when you dont know which way an ambulance is coming from lt;lt;',
#  'reuters twelve feared killed in pakistani air ambulance helicopter crash http  tco shzpyiqok5',
#  'http  tco pwwpum6rbj twelve feared killed in pakistani air ambulance helicopter crash http  tco yspon4d6qo',
#  'why is there an ambulance right outside my work',
#  '\x89ûïleoblakecarter this dog thinks hes an ambulance  http  tco mg1lpgr0rm\x89û\x9dnatasharideout',
#  'happening now  hatzolah ems ambulance responding with dual sirens and\x89û https  tco sek6mq6njf',
#  'http  tco fuerk0gwui twelve feared killed in pakistani air ambulance helicopter crash http  tco mv7ggglmvc',
#  'http  tco x5yeuylt1x twelve feared killed in pakistani air ambulance helicopter crash http  tco 2ugrmd1z1n',
#  'twelve feared killed in pakistani air ambulance helicopter crash http  tco th9ywbbeet worldnews',
#  'twelve feared killed in pakistani air ambulance helicopter crash http  tco x2qsjod40u worldnews',
#  'whats the police or ambulance number in lesotho any body know',
#  'medic914 aaceorg i am surprised we still cannot standardised the clinical practice across the 11 nhs ambulance trust',
#  'http  tco j8tyt1xrrk twelve feared killed in pakistani air ambulance helicopter crash http  tco 9d4nazoi94',
#  'people who try to jwalk while an ambulance is passing i hate you',
#  'the episode where trunks annihilated freiza is the cleanest shit ever he showed that nigga no mercy',
#  'they shall be annihilated and all of their petebests dessicated and laid bare then you shall kneel before me',
#  'uribe just annihilated that baseball mets',
#  'marksmaponyane heysundowns were annihilated in their previous meeting with celticindeed its an improvement',
#  'volfan326 tneazzy mizzou has annihilated florida the past 2 seasons even ended muschamps career just cant compete with bama',
#  'annihilated abs   http  tco 1xpw292tje',
#  'be annihilated for status education mba on behalf of a on easy street careen eovm http  tco e0pi0c54ff',
#  '*to luka* they should all die all of them everything annihilated  alois trancy',
#  'acarewornheart have a good un fella sorry i wont be there to get annihilated with you',
#  'cop pulls drunk driver to safety seconds before his car is hit by train http  tco thrhkhogcuåê http  tco tzszmf2qxe via viralspell',
#  'you must be annihilated',
#  'cop pulls drunk driver to safety seconds before his car is hit by train http  tco c0nkgp6w03åê http  tco imwmfdjssn via viralspell',
#  'boom your country was just entirely annihilated by a h\x89û \x89ûó britain https  tco irfcn71szv',
#  'amirkingkhan you would have been annihilated so you might as well thank floydmayweather',
#  'one thing for suregod has promised israel will not be annihilated butthe horror of iran w nukes https  tco xn09mx6sxy',
#  'violentfeminazi i guess thats ok for armenians since weve spent most of our history getting annihilated',
#  '70 years since we annihilated 100000 people instantly and became aware that we have the ability to annihilate the whole of humanity',
#  'day 1 of tryouts went good minus the fact i stopped quickly to get a short ball and annihilated my toenail injury even more',
#  'during the 1960s the oryx a symbol of the arabian peninsula were annihilated by hunters  http  tco yangeqbuqw http  tco jq2eh5kglt',
#  'to luka they should all die all of them everything annihilated  alois trancy',
#  'ready to get annihilated for the bucs game',
#  'philipduncan breakfastone people annihilated by last nights weather really philip thought you would have forecast that',
#  'domain other sophistication be annihilated closely uptotheminute feat zrnf',
#  'stormbeard steellord i seen judas priest in 2005 when rob came back; scorpions as support fucking annihilated the place astonishing gig',
#  'officially skipping out on fantasticfour fant4stic whatever the hashtag is its getting annihilated in reviews bummer',
#  'tomcatarts thus explaining why you were all annihilated but the few or in this case you the only survivor evolved and became godlike',
#  'just completely annihilated cech with paul keegan what a time to be alive',
#  'tomcatarts who then were annihilated by the legion itself the survivors of the imperfect hybrid project quickly formed a new secret cell',
#  'sirbrandonknt exactly thats why the lesnar cena match from summerslam last year was so great because brock annihilated a guy whos',
#  'cop pulls drunk driver to safety seconds before his car is hit by train http  tco f1bakpnyn6åê http  tco lzxwoaye4x via viralspell',
#  'annihilated in damascus syrian army grinds \x89û÷alloosh and his gang into the manure pile http  tco 7rakhp3bwm',
#  'thatdes ok i wasnt completely forthright i may have also been in a food coma bc of the kebab tahini pickles i also annihilated w fries',
#  'a fun filled happyhour at simmons bar in camden with this handsome one  i got annihilated apart from this game http  tco 4jno677zkv',
#  'juanny beisbol sr annihilated that ball lgm',
#  'rvfriedmann hell is just a fraction of his belief of total annihilation destruction of usa lodisilverado ritzyjewels',
#  'potus maybe we should call israel and tell them were sorry are pres has sold them down the river to annihilation',
#  'evildead  annihilation of civilization http  tco spfke5kqu4',
#  'us national park services tonto national forest stop the annihilation of the salt river wild horse http  tco 6lojoorouk via change',
#  'annihilating quarterstaff of annihilation',
#  'world annihilation vs self transformation http  tco pyehwodwun aliens attack to exterminate humans http  tco pb2n77nskz',
#  'starmade stardate 3 planetary annihilation http  tco i2hhviumtm via youtube',
#  'us national park services tonto national forest stop the annihilation of the salt river wild horse https  tco m8mvdspjp7 via change',
#  'us national park services tonto national forest stop the annihilation of the salt river wild horse https  tco sw1sbua3mn via change',
#  'kimkardashian can you please sign and share this petition to save wild horses in arizona http  tco 3tssxphufe',
#  'us national park services tonto national forest stop the annihilation of the salt river wild horse http  tco kpqk0c4g0m via change',
#  'theellenshow please check into salt river horses help stop the annihilation about to happen without 54000 more signatureschange org thx',
#  'are souls punished withåêannihilation http  tco c1qxjweqqu http  tco zhp0sowxry',
#  'calfreedommom steph93065 not to mention a major contributor to the annihilation of israel',
#  'willienelson we need help horses will dieplease rt amp; sign petitiontake a stand amp; be a voice for them gilbert23 https  tco e8dl1lncvu',
#  'i reject the laws of the misguided false prophets imprison nations fueling self annihilation',
#  'us national park services tonto national forest stop the annihilation of the salt river wild horse https  tco matijwkzbh via change',
#  'the annihilation of jeb christie amp; kasich is less than 24 hours away please god allow me at least one more full day',
#  'barbitwins we need helphorses will die please rt amp; sign petition take a stand amp; be a voice for them gilbert23 https  tco e8dl1lncvu',
#  'whippenz we need help horses will dieplease rt amp; sign petitiontake a stand amp; be a voice for them gilbert23 https  tco e8dl1lncvu',
#  'hey az sign this petition to save the wildhorses  tantonationalforest a rollingstones singalong is in order http  tco wm5l8pj2iy',
#  'stop the annihilation of the salt river wild horses http  tco wvobvvtxkg via change',
#  'sonofbaldwin and hes the current nova in the bookslast i checkedhe was tied into the books in 2011 after rider died during annihilation',
#  'us national park services tonto national forest stop the annihilation of the salt river wild horse https  tco x2wn7o2a3w via change',
#  'please sign amp; rt to save saltriverwildhorses http  tco ikuayuseqt http  tco bqbhuyfme9',
#  'thanks count dante    do join us by following the annihilation zone  johnny',
#  'world annihilation vs self transformation http  tco pyehwodwun aliens attack to exterminate humans http  tco 8jxql8cv8z',
#  'us national park services tonto national forest stop the annihilation of the salt river wild horse https  tco 0fekgyby5f via change',
#  'us national park services tonto national forest stop the annihilation of the salt river wild horse http  tco sb5r7shccj via change',
#  'im gonna fight taylor as soon as i get there',
#  'ohh no fukurodani didnt survive the apocalypse bokuto feels horrible  my poor boy my ppor child',
#  'will there be another jocelyn birthday apocalypse',
#  'rt janenelson097 rt stephenscifi adaptation watch charlie humans apocalypse now now optioned for film sciencefiction \x89û',
#  'apocalypse please',
#  'another hour its august 05 2015 at 0802pm heres red rover zombie apocalypse 2014 http  tco cf9e6tu3g7 internetradio collegeradi\x89û',
#  'honeybunzgem primalkitchen i feel like me doing a pullup is one of the stages of the apocalypse',
#  'shes kinda hot played on the radio today whats next disease to all the apocalypse has started everyone be careful',
#  'but if its the apocalypse lol gf m8',
#  'i know its a question of interpretation but this is a sign of the apocalypse  i called it https  tco my8q1uwijn',
#  'julie + r is the apocalypse version of romeo + juliet warmbodies',
#  'the apocalypse is upon us',
#  'rt fittscott minecraft night lucky block mod bob apocalypse wither 20 amp; more mod showcase popularmmos http  tco mul1j9aeux vi\x89û',
#  'and so it begins day one of the snow apocalypse',
#  'rt ourmothermary short reading  apocalypse 211023   in the spirit the angel took me to the top of an enormous high mountain and \x89û',
#  'candylit imagine sarumi in a zombie apocalypse fighting back to back heart to heart conversations over the http  tco xizkjfff29',
#  'rt zonewolf123 i liked a youtube video http  tco u66kyg11zd minecraft night lucky block mod bob apocalypse wither 20 amp; more mo\x89û',
#  'and thats because on my planet its the lone audience of the apocalypse',
#  'dad bought a dvd that looks like a science doc on the front but i read the back and its actually about the impending biblical apocalypse',
#  'alexandrapullin it is indeed if the apocalypse comes this week i know where ill be',
#  'go look at grizzly peak right now it looks like the beginning of an dystopian apocalypse movie',
#  'my niece just asked me would you be scared if there was an apocalypse here',
#  'theres a storm over cairo in the latest xmen apocalypse set photo https  tco fs012trudg via yahootv',
#  'minecraft night lucky block mod bob apocalypse wither 20 amp; more mod showcase popularmmos http  tco tngye2fklv via youtube',
#  'shot through the heart xv you are going to totally give love a bad name with this heart pierc http  tco xpfmr368uf http  tco ejdhvlkxaf',
#  'rt geekapocalypse 4pm gmt hesse plays dark souls 2 day 9 http  tco tngpshnl87 http  tco imzlnzltf5 etcpb',
#  'i know where to go when the zombies take over http  tco huthxlkyxy',
#  'the latest from bryansinger reveals storm is a queen in apocalypse rupaul alexshipppp http  tco oqw8jx6rts',
#  'shadow boxing the apocalypse',
#  'short reading  apocalypse 211023   in the spirit the angel took me to the top of an enormous high mountain and http  tco v8aftd9zez',
#  'enjoyed liveaction attack on titan but every time i see posters im reminded how freshly clean and coiffed everyone is in the apocalypse',
#  'i liked a youtube video http  tco ki1ykrs9fi minecraft night lucky block mod bob apocalypse wither 20 amp; more mod showcase',
#  'pbban temporary300 avysss armageddon  do not kill  flags only  fast xp for reason',
#  'pbban temporary300 russaky89 armageddon  do not kill  flags only  fast xp for reason',
#  'official vid doublecups gt;gt; https  tco lfkmtzaekk gt;gt; trubgme prod thisizbwright gt;gt; armageddon',
#  'ouvindo peace love amp; armageddon',
#  'best movie youve ever seen  armageddon  http  tco qouxigdtbz',
#  'bed time dont wake me up unless revolution or armageddon start',
#  'red faction armageddon  microsoft xbox 360 2011  full read by ebay http  tco ypbvs1ijya http  tco 9dflv6ynqr',
#  'katiekatcubs you already know how this shit goes world series or armageddon',
#  'rt ophiuchus2613 love truelove romance lith  voodoo seduction astrology rtrrt lotz 911 apocalypse armageddon 1008pla\x89û',
#  'im gonna beat armageddon as hsu hao  just got a flawless on my first try',
#  'enews ben afflecki know theres a wife kids and other girls but i cant help it ive loved him since armageddon eonlinechat',
#  'if id have had a long coat to hand id have worn it the certainty of armageddon bears a sense of occasion',
#  'your phone is spying on you hidden back door nsa data mining software  the financial armageddon blog http  tco qycw5jjaj1',
#  'pbban temporary300 hyiderghost2 armageddon  do not kill  flags only  fast xp for reason',
#  'rt rtrrtcoach love truelove romance lith  voodoo seduction astrology rtrrt lotz 911 apocalypse armageddon 1008planet\x89û',
#  'pbban temporary300 fighterdena armageddon  do not kill  flags only  fast xp for reason',
#  'photo sketch i did based on the a taste of armageddon episode of startrek tos http  tco a2e6dcsk88',
#  'armageddon https  tco ucsudk3q1d',
#  'aberdeenfc aberdeenfanpage   good luck to the  tomorrow night   get some coefficient points plz  armageddon',
#  'paddytomlinson1 armageddon',
#  'rohnertparkdps youre another one for the history books thank the justice department and by the way i havent paid income tax in 20yrs',
#  'vladimir putin issues major warning but is it too late to escape armageddon http  tco gbxafy1m1c',
#  'gods kingdom heavenly govt will rule over all people on the earth after armageddon  http  tco 8hgcbxukz0  http  tco 4kopkcyvtt',
#  'l b entertainment lot of 8 brucewillis movies dvd die hard 1 2 12 monkeys armageddon sixth ebay auction http  tco cxdjapzxmp',
#  'let\x89ûªs talk some more about your goof guild saunders come right up here on stage https  tco hkbxxvd9iw',
#  'karnythia my niece is gaining the ability to stand im getting prepared for toddler apocalypse armageddon',
#  'check out preppers doomsday must have library collection on cd shtf preppertalk survival 2a prepper http  tco vpqtgeqlma via ebay',
#  'erker again eep thought of you yesterday when i saw that hella scary hail armageddon',
#  'so the ahamedis think the messiah had already come 125 years ago where is armageddon where is the dajaal where is gog amp; magog',
#  'sadly how windows 10 reveals microsofts ethics armageddon http  tco stftjcrjea',
#  'armageddon averted by el patron ultimalucha',
#  'samihonkonen if you have the time 23 hours  the latest series about ww1 blueprint for armageddon is extremely impressive',
#  'european fitba till christmas  armageddon',
#  'christians united for israel cufi jews should convert soon or die by armageddon https  tco 4arwwrzpsr us http  tco mkjq9yfmp8',
#  'official vid gt; doublecups gt;gt; https  tco lfkmtzaekk gt;gt; trubgme prod thisizbwright gt;gt; armageddon',
#  'tomorrow is the day we start armageddon preseasonworkouts',
#  'lee does comedy \x89ûïleejasper working class tories prepare for your armageddon interestraterise\x89û\x9d',
#  '9 charts prove financial crisis part 2 has begun the financial armageddon economic collapse blog tracks tren http  tco vhcxtvcinr',
#  'paul craig roberts \x89ûò vladimir putin issues major warning but is it too late to escape a http  tco nvfkzv5fex brics roberts russia',
#  'rohnertparkdps youre on stage now right under the lights isnt it funny where do you get the goofballs with which you staff your pd',
#  '**official vid** thereal gt;gt;gt; https  tco 4i0rjc9rqu gt;gt;gt; trubgme gt;gt;gt; armageddon comin soon',
#  'well done celtic fingers crossed for aberdeen tomorrow night  armageddon eh',
#  'beyonce is my pick for http  tco nnmqlz91o9 fan army beyhive http  tco o91f3cyy0r 77',
#  'one direction is my pick for http  tco q2eblokeve fan army directioners http  tco encmhz6y34 x1402',
#  '5 seconds of summer is my pick for http  tco j6wseptxga fan army 5sosfam http  tco qwgiwc9w7z',
#  '22beyonce is my pick for http  tco thoyhrhkfj fan army beyhive http  tco wvj39a3bgm',
#  '17beyonce is my pick for http  tco thoyhrhkfj fan army beyhive http  tco wvj39a3bgm',
#  'one direction is my pick for http  tco q2eblokeve fan army directioners http  tco encmhz6y34 x1411',
#  'seeing that army of whitewalkers was the very first thing that has slightly intrigued me on got so far',
#  'build your own kingdom and lead your army to victory https  youtu  start g this friend code lzktjnox http  tco zz0cewew64',
#  'salvation army hosts rally to reconnect fathers with children the salvation army is hosting a back to school rally\x89û http  tco rdjpor3azg',
#  'vote for directioners vs queens in the 5th round of the billboard fanarmyfaceoff http  tco kgtxnnbj7y',
#  'but if you build an army of 100 dogs and their leader is a lion all dogs will fight like a lion',
#  'show me a hero tv review http  tco kaccpk85wf http  tco nnixodhigc',
#  'one direction is my pick for http  tco q2eblokeve fan army directioners http  tco encmhz6y34 x1392',
#  'infantry mens lume dial army analog quartz wrist watch sport blue nylon fabric   full rea\x89û http  tco hep9k0xghb http  tco 80ebvglmra',
#  'one direction is my pick for http  tco q2eblokeve fan army directioners http  tco encmhz6y34 x1441',
#  'victorinox swiss army date womens rubber mop watch 241487 http  tco yfy3nkkcoh http  tco knehvvohvk',
#  'rt drayesha4 indiakomuntorjawabdo  indian army ki\x89û http  tco wjljq3ya4g',
#  '5 seconds of summer is my pick for http  tco qchv3jqovk fan army 5sosfam http  tco gc0udfnfgg  ìñ1',
#  'beyonce is my pick for http  tco nnmqlz91o9 fan army beyhive http  tco o91f3cyy0r 78',
#  'one direction is my pick for http  tco q2eblokeve fan army directioners http  tco encmhz6y34 x1386',
#  'you da one   mtvsummerstar videoveranomtv  mtvhottest britney spears lana del rey',
#  'one direction is my pick for http  tco y9wvqkgbbi fan army directioners http  tco s5f9fcomp8',
#  'stony jackson is americas last hope as he leads an army of felons thus and army rejects against the army o satan  http  tco 0wbecdmhqo',
#  'wwi wwii japanese army navy military japan leather watch war mido ww1 2  full read by ebay http  tco f9j3l2yjl4 http  tco mwwwowcayo',
#  'beyonce is my pick for http  tco nnmqlz91o9 fan army beyhive http  tco o91f3cyy0r 72',
#  '7beyonce is my pick for http  tco thoyhrhkfj fan army beyhive http  tco wvj39a3bgm',
#  'beyonce is my pick for http  tco nnmqlz91o9 fan army beyhive http  tco o91f3cyy0r 66',
#  '6beyonce is my pick for http  tco thoyhrhkfj fan army beyhive http  tco wvj39a3bgm',
#  'potus appoints brig gen richard g kaiser as member of the mississippi river commission learn more about the mrc http  tco vdukcv7yjy',
#  'ap what a violent country get the army involved to help control the killings and bring back peace to the poor people',
#  'wwi wwii japanese army navy military japan leather watch war mido ww1 2  full read by ebay http  tco qumce7w2ty http  tco ktkg2sdhhl',
#  'wwi wwii japanese army navy military japan leather watch war mido ww1 2  full read by ebay http  tco obfd7e4qcp http  tco yazje5owvk',
#  'one direction is my pick for http  tco q2eblokeve fan army directioners http  tco encmhz6y34 x1434',
#  'one direction is my pick for http  tco imhfdaowrd fan army directioners http  tco 4ftzjk94dt',
#  'two jewish terrorists charged in historicchurch arson  the ugly truth http  tco ieksnfsby7 http  tco vwcf3slkrw',
#  'spokane authorities say theyre struggling to solve arson cases like todays on hamilton http  tco qbs2k01wzk http  tco mvlziysgll',
#  'thousands attend a rally organized by peace now protesting the arson attack that took the life of an http  tco bvckd9pdti',
#  'add familia to the arson squad',
#  'another fake hate crime lesbians burn their own house down what else is new http  tco 66obqmximb',
#  'los angeles times arson suspect linked to 30 fires caught in northern   http  tco xwms1aww8m newsintweets http  tco te2yerugsi',
#  'mourning notices for stabbing arson victims stir \x89û÷politics of grief\x89ûª in israel http  tco eug6zhciun',
#  'mourning notices for stabbing arson victims stir \x89û÷politics of grief\x89ûª in israel http  tco kkbxiblah7',
#  'the sound of arson',
#  'owner of chicagoarea gay bar admits to arson scheme http  tco myhohvrhil lgbt  https  tco tm5hthfdo0',
#  'wait what http  tco uavfrtlfs4 http  tco 85g1pcccxg',
#  'arson suspect linked to 30 fires caught in northern california http  tco ej2ghnafhy',
#  'trial date set for man charged with arson burglary http  tco wftcrlz32p',
#  'after death of palestinian toddler in arson attack israel cracks down on jewish',
#  'palestinian teen killed amid protests against arson attack http  tco okvsimogic',
#  'kisii police in kisii hunt for students over failed arson plot police in kisii hunt for students http  tco m5sbfrrsn7 countynews',
#  'mariah getting thick in the shoulders poor girl',
#  'mourning notices for stabbing arson victims stir \x89û÷politics of grief\x89ûª in israel posters for shira banki and a http  tco 3gz5zqqthe',
#  'relaxinpr miprv rt latimes arson suspect linked to 30 fires caught in northern california http  tco ylhayfaoou',
#  'jewish leaders prayed at the hospital where a palestinian family is being treated after arson http  tco wf8itk2kvx via huffpostrelig',
#  'owner of chicagoarea gay bar admits to arson scheme http  tco 0tslqjokvh via theadvocatemag lgbt',
#  'saynae angel or arson',
#  'kisii police in kisii hunt for students over failed arson plot police in kisii hunt for students http  tco 5bdrfu1duo countynews',
#  'mourning notices for stabbing arson victims stir \x89û÷politics of grief\x89ûª in israel http  tco q4l7dg56jm',
#  'owner of chicagoarea gay bar admits to arson scheme http  tco 2y9dnp5vtg via theadvocatemag lgbt  https  tco 6xul6dcosh',
#  'owner of chicagoarea gay bar admits to arson scheme http  tco ubfr1urafc lgbt  https  tco alnv51d95x',
#  'mourning notices for stabbing arson victims stir \x89û÷politics of grief\x89ûª in israel http  tco gbluhrrlto',
#  'owner of chicagoarea gay bar admits to arson scheme http  tco zpxe3fmyng lgbt',
#  'arson suspect linked to 30 fires caught in northern california http  tco wnuqqatttp via latimes',
#  'tennessee lesbian couple faked hate crime and destroyed own home with arson\x89û http  tco 10muey8pxj lesbian',
#  'arson suspect linked to 30 fires caught in northern california  los angeles times http  tco prrb4fhxtv',
#  'arson suspect linked to 30 fires caught in northern california http  tco u1fuwrgk5u',
#  '301dc cloudygoldrush i hate white people mo',
#  'nowplaying arsonist mc   so impressed   arsonistmusic http  tco 1elreh1jlj',
#  'alleged east bay serial arsonist arrested http  tco wr48aqtum7',
#  'safyuan just a minor citation for possesion of a decriminalized substance im not facing any time',
#  'suspected serial arsonist arrested in calif http  tco pzotpdgaki',
#  'arson suspect linked to 30 fires caught in northern california http  tco mmgsyahdzb',
#  'localarsonist diamorfiend the legal system never forgets',
#  'casperrmg u on dick',
#  'bloor ossington arsonist also burned a mattress on northumberland st cbcto http  tco wpdvt31sne',
#  'wheres my arsonist at',
#  'if you dont have anything nice to say you can come sit with me',
#  'vegetarian vegan video shows arsonist torching popular bk restaurant strictly vegetarian http  tco kxplyom9rr govegan uniteblue',
#  'arsonist arrested for setting many fires watch tonight\x89ûªs other headlines http  tco sqgogj3s5r nightbeat veronicadlcruz 2minutemix',
#  'video captures man removing american flag from long beach ca home burning it; arsonist sought http  tco jp2qlrunjj http  tco jbpgkgowsi',
#  '58hif my trick is to think about nasty things',
#  'spotlight take me to paradise by arsonist mc wniagospel http  tco 1he4ufawzm arsonistmusic http  tco bnhtxaezmm',
#  'who makes these http  tco 28t3nwhdky',
#  'on town of salem i just melted ice cube bc im the arsonist d',
#  'arsonists being blamed for a blaze at a plastics recycling business in adelaide  pcaldicott7 reports 7newsadl http  tco r1xwdnvb0g',
#  'i be on that hotboy shit',
#  'zodiac girl feat trey dupree produced by sparkz beatz  chuck da arsonist http  tco hdkd9j2lw0',
#  'localarsonist lmfao',
#  'alleged east bay serial arsonist arrested sanfrancisco  http  tco ojuhfkhvb2',
#  'doofus diamorfiend im jokin still cant be on moves',
#  'localarsonist i guess u can say that its just some shit i was thinking about',
#  'arsonist sets nyc vegetarian restaurant on fire police newyork  http  tco nr7ust3uh8',
#  'i liked a youtube video from slimebeast http  tco ulr6myklnh town of salem  how to win as the arsonist',
#  'casperrmg bestcomedyvine whats cracking cuz',
#  'smoke good fuck eat drink drive nice car wear all green mink',
#  'kill i got court the day after earl',
#  'localarsonist lmao but real live you should go',
#  'owner of chicagoarea gay bar admits to arson scheme frank elliott pleaded guilty to hiring an arsonist to to http  tco jcfehrhlq8',
#  'trusting iran to stop terrorism is like inviting an arsonist to join the fire brigade  telegraph http  tco 2z2htdjqzd',
#  'big top burning the true story of an arsonist a missing girl \x89û  http  tco qxh1h61cwd',
#  'stay vigilent civil liberties are under constant attack nativehuman myreligion  https  tco wwu070tjej',
#  'credit to pfannebeckers for inspiring me to rediscover this fantabulous tbt http  tco wmhy47xkil',
#  'http  tco ptkrxtzjtv  nashville theater attack will gun grabbers now demand \x89ûïhatchet control\x89û\x9d',
#  'breaking terror attack on police post udhampur',
#  'demi stans really think heart attack sold 5 6 million copies',
#  'it scares me that theres new versions of nuclear attack warnings like just knowing that governments still prepare for them',
#  'isil claims suicide bombing at saudi mosque that killed at least 15 http  tco y8icf89h6w http  tco t9msnzv1kb',
#  'dattomm the funniest part about that twitter is the feminists that try to attack it 4head',
#  'horrific attack on wife by muslim in italy http  tco ny3l1orzqb liveleak news',
#  '\x89ûª93 blasts accused yeda yakub dies in karachi of heart attack http  tco mfkqyxd8xg mumbai',
#  'etribune  us drone attack kills 4suspected militants in north waziristan acebreakingnews https  tco jb038rdfak',
#  'suspect in latest theater attack had psychological issues http  tco 3huhzxliig',
#  'militants attack police post in udhampur; 2 spos injured  livemint http  tco rptouz2ijs  http  tco 69mlhfefhr allthenews',
#  'breaking obama officials gave muslim terrorist the weapon used in texas attack http  tco qi8qdw5dfg',
#  'delhi government to provide free treatment to acid attack victims in private hospitals http  tco h6pm1w7ell',
#  'new post from darkreading http  tco 8eijdxapnp new smb relay attack steals user credentials over internet',
#  'israeli forces raid home of alleged car attack suspect http  tco 3gvus8nppy palestine',
#  'just had a heart attack because i thought my goat was dead  dont worry rocket is okay',
#  'im not gonna lie im kinda ready to attack my senior year',
#  'left hand side of a diamond is a graveyard shift have to attack and defend the right handside no have to do that too you fucking idiot',
#  'volleyball attack ii volleyball training machine  sets simulation  http  tco dcdecfv934 http  tco dwbc1duvdk',
#  'notleys tactful yet very direct response to harpers attack on albertas govt hell yeah premier http  tco rzsulzmokx ableg cdnpoli',
#  'police assailant in latest us movie theatre attack was homeless had psychological issues http  tco zdcvlyq6qk',
#  'caixxum5sos thanks for the damn heart attack',
#  'suspect in latest us theatre attack had psychological issues http  tco onpnbx0zex http  tco um5icn5et2',
#  'india shud not give any evidence 2 pakthey will share with terrorists amp; use for next attackshare with oth contries https  tco qiopbtiuvu',
#  'illegal alien released by obama dhs 4 times charged with rape amp; murder of santa maria ca woman had prior offenses  http  tco mqp4hf9gpo',
#  'strongly condemn attack on ary news team in karachi a cowardly act against those simply trying to do their job',
#  'nashville theater attack will gun grabbers now demand \x89ûïhatchet control\x89û\x9d  http  tco oyogii97yh',
#  'the fact that the atomic bombs were called little boy and fat man says a lot about the mentality that went into the attack',
#  'blazerfan not everyone can see ignoranceshe is latinoand that is all she can ever benothing morebut an attack dog 4 a hate group gop',
#  'heart disease prevention what about secondhand smoke http  tco ydgmgbryl2',
#  'a daytonarea org tells me it was hit by a cyber attack http  tco 7lhkjz0ivo',
#  'attack on titan game on ps vita yay cant wait for 2016',
#  'infowars  nashville theater attack will gun grabbers now demand \x89ûïhatchet control\x89û\x9d http  tco n3yjb8tcpm nwo',
#  'anxiety attack',
#  'my dog attacked me for my food pugprobs',
#  'cop injured in gunfight as militants attack udhampur police post suspected militants attacked a police post i http  tco 2h0dpmv2ef',
#  'envw98 nickcocofree juliedicaro jdabe80 i asked how did he feel attacked by julie  i asked if he was frail   that is all',
#  'messeymetoo i feel attacked',
#  'im feeling so attacked https  tco cvkqigr1az',
#  'once again black men didnt make it that way white men did so why are black men getting attacked  https  tco chkp0gfynj',
#  'i cant believe a fucking cis female is going to somehow claim to be offended over a transgendered female whos been attacked by media',
#  'israeli helicopters that attacked civilians in gaza just completed exercises in greece',
#  'christian attacked by muslims at the temple mount after waving israeli flag via pamela geller   http  tco 5qyczywkgg',
#  'christian attacked by muslims at the temple mount after waving israeli flag via pamela geller   http  tco u0keoe5fmt',
#  'christian attacked by muslims at the temple mount after waving israeli flag via pamela geller   http  tco f5miuhqaby',
#  'pt the unit attacked by is was responsible for targeting muslim scholars and imprisoning the youth http  tco f4lhfmehzh',
# ...
#  'the best thing at dq is the cotton candy blizzard',
#  'lizard wizard in a blizzard lwb http  tco mgr809yc5a',
#  'blizzarddraco lonewolffur i need this',
#  'fairx818x playoverwatch blizzardcs please blizzard we love you',
#  'a blizzard would be clutch asf',
#  'blizzarddraco lonewolffur also me please i would very much like a link',
#  'bubblycuteone  ok ok okayyyyyy ima act right bout to get this blizzard tho',
#  'lonewolffur control yourself tora',
#  'first time playing hearthstone on pc thoughts http  tco abolxmh1vy',
#  'i love the cotton candy blizzard',
#  'tcgreno just hard reset my xbox',
#  'i really wanna brownie batter blizzard',
#  'i call it a little bit of your blizzard',
#  'market news activision blizzard cognizant technology first solar http  tco gknrp0e8qs',
#  'sean end career sg blizzard vs knockout  http  tco nyv51681ue',
#  'what is the biggest regret you have in hearthstone http  tco vcirn1md8v',
#  'someone walk with me to dq  i wanna butterfinger blizzard so bad',
#  'that horrible moment when u open up the dryer and it looks like a snowy blizzard cuz u left a piece of paper in your jeans pocket',
#  'lonewolffur bruh *dies*',
#  'rip  blood',
#  'chiefcg nah young blood that cook is gone im cut now haha',
#  'off the wall invincible and history + blood on the dance floor https  tco zntg2wndmj',
#  'broke my nailreal not fake this morning blood and all ah it hurts any ideas how to treat it help me pretty please',
#  '45 out of 5 stars by 290 reviewers for dragon blood boxset by lindsay buroker http  tco 4yu5sy1cui kindle http  tco mzmxmyklxv',
#  'blood group  a +ve is associated with gastric carcinoma says text bookanother fragile gene in my body',
#  'a friend is like blood they are not beside us always but they come out when we are wounded',
#  'we gone get it  get it in blood',
#  'people with a tattoo out there are u allowed to donate blood and receive blood as well or not',
#  'doing dialyses to my grandpa and oh lord this blood makes me light headed',
#  'setzorah dad why dont you claim me that mean that not right we look the same same eyes same blood same xbox 360 smh',
#  'omron hem712c automatic blood pressure monitor standard and large bp cuffs http  tco gjbainqwn9 http  tco jphgpl1c5x',
#  'my blood pressure is through the roof i dont need all this extra shit',
#  'chamberedblood yeah you are speakingfromexperience',
#  'cant believe more people in their mid 20s dont have high blood pressure life is stressful decisionsondecisions',
#  'guys i have an imouto who isnt actually related to me by blood',
#  'bruh white people buy the ugliest shoes and they them super tight no blood going to there feet',
#  'another day another excellent dangerousbeans porridge seriously people blood orange in porridge is phenomenal',
#  'scotto519 happy birthday young blood',
#  'if it wasnt for the blood',
#  'no kinda in it that shii nasty blood no pun intended',
#  'aint no hoe in my blood',
#  'today was such a hastle from getting drug tested  blood drown out  tb shot  to document filling',
#  'man  somebody gotta stop sbee dude too fuckin funny blood',
#  'where will the winds take my gypsy blood this time http  tco 66yvulizbk',
#  'loboparanoico mad men',
#  'private thirsty nightsad blood rockn roll',
#  'rolandonabeats ellie goulding  my blood  acesse nosso site para ouvir http  tco zk69ugxmt8',
#  'olrules welcome  read a free chapter of my new book encounters with jesus its full of hope http  tco 6qx7arf4ag',
#  'anthxvy runs in the blood',
#  'sethalphaeus my personal favorites include paramore muse green day royal blood and 5sos',
#  'shed innocent blood of their sons and daughters and the land was polluted psalms 10638  help stop the sin of abortion',
#  '*se pone a cantar crying lightning*',
#  'it wasnt a very big stab but it was a deep stab and theres like blood everwhe',
#  'add these items to your everyday eating habits please do the research on how to take with your blood\x89û https  tco lnpscadaxr',
#  'looooooooooool who the bloody hell did that  https  tco jrkgyl7te5',
#  'infected bloody ear piercings are always fun',
#  'aggressif is so bloody aggressive',
#  'i entered to win the entire set of butterlondon lip crayons via beram0s  go enter bbloggers http  tco dsb3ldfuxu',
#  'slsandpet hey sally sorry have you emailed me been awol bloody work argh resigninshame',
#  'im over here listening to bloody jay   https  tco ciyty0fgpr',
#  'lauradeholanda i have the forrest version from 83 thats bloody awful as well  xxx',
#  'a nightmare on elm street is getting remade again  http  tco hvwkjqxxyt',
#  'i cant bloody wait sony sets a date for stephen king\x89ûªs \x89û÷the dark tower\x89ûª stephenking thedarktower http  tco j9lpdrxcde  bdisgusting',
#  'gotta try to let go of so many bloody things smh',
#  'tradcatknight 1 russia may have played into reason but that link is bs  okanowa was bloody and mainline invasion looked like a bloody',
#  'bloody insomnia again grrrr insomnia',
#  'zhenghxn i tried 11 eyes akame ga kill and tokyo ghoul all damn bloody i dont dare watch',
#  'fantosex now suck it up because thats all youre bloody getting out of me by means of amends',
#  'you call them weekends i call them bloody mary times this summers been full of them my new\x89û https  tco vnni3zzuz6',
#  'bloody hell what a day i havent even really done anything just tired of everything thought vaca would help but it only did so much =',
#  'damn bloody hot',
#  'mrtophypup its bloody sexy *drools*',
#  'you know how they say the side effects low amp; really fast son the product was an acne cream why 1 of the side effects was bloody diarrhea',
#  'ronda rousey would be close to making floyd mayweathers money in 50 fights  bloody elbow http  tco ijzcytbffo boxing',
#  'im awful at painting why did i agree to do an a3 landscape in bloody oils of all paints',
#  'all i need in this life of sin is just me and my girlfriend down to ride till the bloody end just me and my girlfriend',
#  'itsmegss i think it is well its bloody barking now',
#  'eh hello cover your bloody thighs your bloody cleav \x89ûó eh hello since when do i expose my cleavage and i on http  tco kv5l4ppxfg',
#  'mariasherwood2 johnjcampbell mega bloody marvellous',
#  'bloody mary in the sink beet juice http  tco luigmhma1i',
#  'melrises gayler1969 wwwbigbaldhead jessienojoke melissaross9847 if my monty python is up to date as bloody far as he wants to go',
#  'meet the bloody rs5 http  tco rvczmimfvx',
#  'friday supposed to be a happy day but its a bloody friday hah zzzz',
#  'chxrmingprince jonesluna i should bloody hope so *she said folding her arms sitting back in her chair*',
#  'wait until i tell my college friend who reafs bloody mary too about the drama cd',
#  'i came to kill indiansfor fun video of smirking and remorseless pakistani killer shows him boasting http  tco fpjlwoxklg',
#  'ive just watched episode s01e09 of bloody monday http  tco vrpthvpymt bloodymonday tvshowtime http  tco nkkvknbvoz',
#  'marlon williams gt; elvis presley gt; marlon williams gt; steel panther   shuffle mode like a bloody legend',
#  'black friday turns bloody would rather be shopping http  tco l0pmmtzlwp  mystery',
#  'ezralevant someone told me all the soccer moms are getting this pic blown up and put on their daughters bedroom walls not',
#  'papcrdoll and i s2g if my mentions get blown up over my choice i will deactivate and leave for good respect my choices',
#  'manutd emilymcfcheslop   wow just wow   if any other club had blown all that money and fucked up a player like that theyd be pilloried',
#  'damn greinke got blown up in that first inning',
#  'woke up so blown lol',
#  'aunt marge youre blown up eheks',
#  'troylercraft yeah its not worth it bc he already has so many spammers amp; his twitter is probably blown up every second',
#  'white family supposedly representing americas great values  gets blown up in a horrible cgi nuclear strike lmfaoooo',
#  'man why hasnt machinegunkelly blown up hes still underground',
#  'and my mentions are blown up for what  wtf',
#  'on thisdayinhistory in 1862 confederate ship blown up by crew read more http  tco iw7elszifz via history',
#  'that moment when ur about to win a mini uhc and than get blown up by a creeper and get kicked for flying so salty rn',
#  'libraryeliza he did get a taylorswift13 bump of approval which is probably why hes blown up http  tco kolmzbz1pz musicadvisory',
#  'if a truckload of soldiers will be blown up nobody panics but when one little lion dies everyone loses their mind http  tco wjntaokdhf',
#  'hey look  kashs foundation live for today got blown up on people magazines website    todd blake http  tco 2fenu1syu6',
#  'kaylak369 got it last month when i went into the ee shop glad it hasnt blown up yet http  tco pgb2bmcfx8',
#  'this is the first time a tweet has blown up almost half a day later re https  tco 1buf0xm53d',
#  'we\x89ûªre blown away by this extension nothing we\x89ûªve seen has as many options as this one https  tco 0yzgw9zbhr  https  tco rhtaqjvqn2',
#  'theboyofmasks thanks again for letting me stay here since the manor was blown up anyways how are you doing buddy',
#  'loner diaries  the patterns  on the sand may have been blown away the photos in twos all choked up in flames http  tco ekfaz6wvbz',
#  'even though bsg had been sufficiently hyped up for me in all the years i somehow delayed watching it i was utterly utterly blown away',
#  'vanessas game has officially blown up ladies and gentlementhe real show is about to begin bb17',
#  'guaranteed been bitten by some mutant mosquito my ankle has blown up little cunts',
#  'things you can pick up from tozlet seat butt leprosy fullblown jerkface syndrome a lateral lisp amp; toilet rickets',
#  'kalinandmyles kalinwhite my ig is being blown up just with hackers i need it to stop givebackkalinwhiteaccount',
#  'lukewinkie whoever is directing these videos needs to grab up nicki minaj or someone with us recognition so minds can be blown',
#  'princessduck last week wanted the 6th sense to get blown up so far so good james could win but hes a huge target and will be gone soon',
#  'orbette more like blown up amirite',
#  'my dog\x89ûªs just blown his kennel up \x89ûò bloody yorkshire terrorist',
#  'turn on espn2 and get blown up',
#  'hopefulbatgirl went down i was beaten and blown up then next thing i know ra al ghul brought me back to life and i escaped and for a',
#  'thebriankrause leos ass just got metaphorically blown up again piperwearsthepants charmed',
#  'anarchicteapot boironusa zeno001 glononium 6c also helps with being blown up while bashing a bottle of nitroglycerin against a book',
#  'new ladies shoulder tote handbag women cross body bag faux leather fashion purse  full re\x89û http  tco y87gi3brlv http  tco 1zbhvdcxzs',
#  'new ladies shoulder tote handbag women cross body bag faux leather fashion purse  full re\x89û http  tco blaawhysct http  tco ddr0zjxvqn',
#  'if you have a son or a daughter would you like to see them going to a war with iran and come back in a body bag let the republicans know',
#  'questergirl ditto but its all we had and the way i feel if i drank vodka over ice they would have to body bag me',
#  'handbags genuine mulberry antony cross body messenger bag dark oak soft buffalo leather  å£27900end date w http  tco ftm4rkl8mn',
#  'louis vuitton monogram sophie limited edition clutch cross body bag  full read by ebay http  tco jrxgolnpqw http  tco lin16kvzbn',
#  'louis vuitton monogram sophie limited edition clutch cross body bag  full read by ebay http  tco gggfvo5pb4 http  tco nlfr8t3xqm',
#  'louis vuitton cultsierre monogram shoulder bag cross body bag  http  tco muf5czqjrl http  tco sslt8esmhy',
#  'check out ameribag healthy back bag shoulder cross body backpack khaki tan beige nylon http  tco r4k7tylofj ebay',
#  'photo bath amp; body works cosmetic bag in periwinkle blue with copper piping along the top and four corners http  tco a9bnlse6qb',
#  'new ladies shoulder tote handbag women cross body bag faux leather fashion purse  full re\x89û http  tco 3pcntczoxv http  tco n0akjm1e4b',
#  'new summer long thin body bag hip a word skirt blue http  tco lvkoemsq8m http  tco cjirhhh4vj',
#  'å¤} new ladies shoulder tote handbag faux leather hobo purse cross body bag womens http  tco uoozxaus26 http  tco 6mgbizjfgd rt en\x89û',
#  'trjdavis bruh you wanna fight im down meet me in the cage bro better find out who youre dealing with before you end up in a body bag',
#  'new ladies shoulder tote handbag faux leather hobo purse cross body bag womens  full read\x89û http  tco 4fxfllrien http  tco i12nlsr8fk',
#  'auth louis vuitton brown saumur 35 cross body shoulder bag monogram 723 4193  full read\x89û http  tco hcdiwe5flc http  tco zlvebeoavg',
#  'check out vintage longaberger floral fabric shoulder cross body bag brown leather strap http  tco fb8snrg4hu ebay',
#  'new ladies shoulder tote handbag faux leather hobo purse cross body bag womens http  tco zujwuiomb3 http  tco gbctmhx7pw',
#  'new summer long thin body bag hip a word skirt blue http  tco 8jymd9ypsj http  tco 57pkmmcadg',
#  'ìü new ladies shoulder tote handbag faux leather hobo purse cross body bag womens http  tco uoozxaus26 http  tco pw78nbljky rt en\x89û',
#  'louis vuitton monogram sophie limited edition clutch cross body bag  full read by ebay http  tco i4aogcsoy5 http  tco djiwg9pxv4',
#  'new women handbag faux leather ladies shoulder tote cross body bag large satchel  full re\x89û http  tco ncjpgf6znv http  tco gerjau74ey',
#  'new ladies shoulder tote handbag faux leather hobo purse cross body bag womens http  tco zujwuiomb3 http  tco iap4lwvqsw',
#  'one day this heart gone get me zipped up in a body bag',
#  'handbag fashion style http  tco ipxpi3me16 authentic louis vuitton pochette bosphore shoulder cross body bag\x89û http  tco rv0fk7q4y5',
#  'å new ladies shoulder tote handbag faux leather hobo purse cross body bag womens http  tco zujwuiomb3 http  tco ykltfj1fnc',
#  'handbag fashion style http  tco hpd3snm6oy vintage coach purse camera bag cross body 9973  $1699 0 bids \x89û http  tco gsmddmu9pu',
#  'genuine leather man bag messenger fit ipad mini 4 tablet case cross body air jp  full rea\x89û http  tco rcburzsb2b http  tco ehsfklgri3',
#  'louis vuitton monogram sophie limited edition clutch cross body bag  full read by ebay http  tco vjgr6liaxh http  tco 55jr66plov',
#  'new ladies shoulder tote handbag faux leather hobo purse cross body bag womens http  tco zujwuiomb3 http  tco cjqq6cgohg',
#  'nuu that fam fwt im leave you in a body bag',
#  'new ladies shoulder tote handbag faux leather hobo purse cross body bag womens  full read\x89û http  tco ur7fexszg4 http  tco wb8awoblcl',
#  'rhee1975 deliciousvomit no im not im saying that theyre lucky they can go home to their families not put in a body bag',
#  'mattbez oh im not bagging her at all her body be bangin im saying shes going to get the rose',
#  'ohmyloz rondarousey who is bagging her body  shes smoking hot',
#  'drake is really body bagging meek',
#  'fuckyeahcarey bornverified drake killing this dude and tea bagging the dead body at this point',
#  'meekmill is wreck league ball drake is olympic level body bagging him like his career was nothing trollingtilmeekdiss',
#  'idgaf who tough or who from canada and who from north philly meek been acting like a bitch amp; drake been body bagging his ass on tracks',
#  'yankees body bagging mfs',
#  'broseidonrex dapurplesharpie i skimmed through twitter and missed this body bagging',
#  'g+ +https  tco dodxi41y1cåêis body bagging them lyrically https  tco hlmyaanrc9',
#  'bomairinge elutranscendent straight body bagging',
#  'body bagging bitches  http  tco afssgpnzwi',
#  'no better feeling than seeing and being on stage with my day ones 22 year friendships and we still body bagging mics together',
#  'mopheme and bigstar johnson are a problem in this game body bagging niggas vuzuhustle',
#  'i was body bagging on the today4got to post my score http  tco 81g18wsauk',
#  'editaxohaze then let the bagging bodys begin lol  i aint cuffed yet so it shouldnt be that bad',
#  ...]

# %%
import string
from nltk.corpus import stopwords 
from nltk import word_tokenize
from nltk.stem import WordNetLemmatizer
import re
lmtzr = WordNetLemmatizer()
def preprocessing(df):
    pattern = r'[0-9]'
    df['text'] = df.text.apply(lambda x: x.strip())
    df['text'] = df.text.apply(lambda x: x.translate(str.maketrans('', '', string.punctuation)))
    df['text'] = df.text.apply(lambda x: x.lower())
    df['text'] = df.text.apply(lambda x: re.sub(pattern, '', x))
    df['text'] = df.text.apply(lambda x:' '.join([lmtzr.lemmatize(w) for w in x.split()]))
    return df['text']

# %%
train['text'] = preprocessing(train)

# %%
test['text'] = preprocessing(test)

# %%
test.isna().sum()
# Out:
# id             0
# keyword       26
# location    1105
# text           0
# dtype: int64

# %%
lista_test = []
i = 0
for keyword,text in zip(test['keyword'],test['text']):
    if str(keyword) == 'nan':
        keyword = str(keyword).lower()
        for keyword in test['keyword']:
            keyword = str(keyword).lower()
            if keyword in text.lower():
                if len(lista_test) < i+1:
                    lista_test.append(keyword)
        if len(lista_test) < i+1:
                    lista_test.append('nan')
    else: 
        lista_test.append(keyword)
    i+=1

# %%
test['keyword'] = lista_test

# %%
train
# Out:
#          id    keyword location  \
# 0         1  earthquak      NaN
# 1         4       fire      NaN
# 2         5      evacu      NaN
# 3         6      evacu      NaN
# 4         7       fire      NaN
# ...     ...        ...      ...
# 7608  10869    collaps      NaN
# 7609  10870       fire      NaN
# 7610  10871    volcano      NaN
# 7611  10872     collid      NaN
# 7612  10873       fire      NaN
#
#                                                    text  target
# 0     our deed are the reason of this earthquake may...       1
# 1                 forest fire near la ronge sask canada       1
# 2     all resident asked to shelter in place are bei...       1
# 3     people receive wildfire evacuation order in ca...       1
# 4     just got sent this photo from ruby alaska a sm...       1
# ...                                                 ...     ...
# 7608  two giant crane holding a bridge collapse into...       1
# 7609  ariaahrary thetawniest the out of control wild...       1
# 7610       m utckm s of volcano hawaii httptcozdtoydebj       1
# 7611  police investigating after an ebike collided w...       1
# 7612  the latest more home razed by northern califor...       1
#
# [7613 rows x 5 columns]

# %% [markdown]
# ## Model

# %%
X_train = train['text']
X_test = test['text']
y_train = train['target']

# %%
X_train
# Out:
# 0       our deed are the reason of this earthquake may...
# 1                   forest fire near la ronge sask canada
# 2       all resident asked to shelter in place are bei...
# 3       people receive wildfire evacuation order in ca...
# 4       just got sent this photo from ruby alaska a sm...
#                               ...
# 7608    two giant crane holding a bridge collapse into...
# 7609    ariaahrary thetawniest the out of control wild...
# 7610         m utckm s of volcano hawaii httptcozdtoydebj
# 7611    police investigating after an ebike collided w...
# 7612    the latest more home razed by northern califor...
# Name: text, Length: 7613, dtype: object

# %%
vectorizer = CountVectorizer(ngram_range = (2,2))
naivebayes = MultinomialNB()

X_bow = vectorizer.fit_transform(X_train)

cv_nb = cross_validate(
    naivebayes,
    X_bow,
    y_train,
    scoring = "accuracy"
)

round(cv_nb['test_score'].mean(),2)
# Out:
# 0.64
